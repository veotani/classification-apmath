# %% [markdown]
# # Работа с поисковыми движками
#
# **Нужно:**
# * выбрать какой-либо новостной ресурс (например http://lenta.ru, http://fontanka.ru, http://gazeta.ru)
# * загрузить новости за пару лет
# * проиндексировать их с помощью Elasticsearch/Solr/чистая Lucene
# * реализовать простой web-интерфес поиска (лучше) или поиск через коммандную строку (хуже)

# %% [markdown]
# ### Elastichsearch
#
# 1. Качаем https://artifacts.elastic.co/downloads/elasticsearch/elasticsearch-6.0.1.zip
# 2. Распаковывам
# 3. Запускаем `bin\elasticseach`
# 4. Ставим клиент для Python `python -m pip install -U elasticsearch elasticsearch_dsl`
# 5. Соединяемся

# %%
from elasticsearch import Elasticsearch

es = Elasticsearch()

# %% [markdown]
# Создаем новый индекс

# %%
es.indices.create(index='test-index')
# Out:
# {'acknowledged': True, 'index': 'test-index', 'shards_acknowledged': True}

# %% [markdown]
# Добавляем новый документ в индекс

# %%
es.index(index='test-index',  doc_type='test',  body={'title': 'Hello', 'content' : 'World hello!'})
# Out:
# {'_id': 'a_kITGABDP7xNZfkjxeJ',
#  '_index': 'test-index',
#  '_primary_term': 1,
#  '_seq_no': 0,
#  '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#  '_type': 'test',
#  '_version': 1,
#  'result': 'created'}

# %% [markdown]
# и ещё один

# %%
es.index(index='test-index', doc_type='test', id=2, body={'title': 'Sun', 'content' : 'shine brightly'})
# Out:
# {'_id': '2',
#  '_index': 'test-index',
#  '_primary_term': 1,
#  '_seq_no': 0,
#  '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#  '_type': 'test',
#  '_version': 1,
#  'result': 'created'}

# %% [markdown]
# Теперь ищем

# %%
a = es.search(index='test-index', doc_type='test', q='sun')
a
# Out:
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 5, 'total': 5},
#  'hits': {'hits': [{'_id': '2',
#     '_index': 'test-index',
#     '_score': 0.2876821,
#     '_source': {'content': 'shine brightly', 'title': 'Sun'},
#     '_type': 'test'}],
#   'max_score': 0.2876821,
#   'total': 1},
#  'timed_out': False,
#  'took': 7}

# %% [markdown]
# ### Выполнение задачи

# %%
import os
from tqdm import tqdm_notebook

file_dir = 'no_normilize/'
files = os.listdir(file_dir)
for file in files:
    id = 1
    with open(file_dir + file, 'r') as f, open('indexes_files/' + file, 'w') as outfile:
        for line in f.readlines():
            outfile.write(str(id) + '\t' + line.replace('\n', '') + '\n')
            id = id + 1

# %%
import os
import pymorphy2
import re

es.indices.create(index='news')
file_dir = 'no_normilize/'
files = os.listdir(file_dir)
normilizer = pymorphy2.MorphAnalyzer()
for file in files:
    with open(file_dir + file, 'r') as f:
        for line in f.readlines():
            #norm_words = [re.sub('\d+', '', normilizer.normal_forms(x)[0]) for x in re.split('\W+', line) if len(x) > 0]
            es.index(index='news', doc_type='new', body={'content' : line})

# %%
a = es.search(index='news-index', doc_type='new', q='парад')
# Out:
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 5, 'total': 5},
#  'hits': {'hits': [{'_id': '5195',
#     '_index': 'news-index',
#     '_score': 9.099816,
#     '_source': {'content': 'в петербург пройти очередной репетиция парад к день вмф по нева днём 23 июль пройти не маленький пятнадцать корабль и катер среди который быть ракетный катер серпухов и димитровград противодиверсионный катер плата 349 малый ракетный корабль гейзер на время репетиция быть развести благовещенский дворцовый троицкий и литейный мост над адмиралтейство пролететь несколько самолёт в тот число дозаправщик и истребитель в петербург пройти очередной репетиция парад к день вмф напомнить парад пройти в петербург и кронштадт 30 июль в немой принять участие корабль балтийский черноморский северный флот каспийский флотилия и авиация тихоокеанский флот принимать парад быть президент следующий репетиция наметить на 28 июль\n'},
#     '_type': 'new'},
#    {'_id': '1482',
#     '_index': 'news-index',
#     '_score': 8.283231,
#     '_source': {'content': 'video над петербург кружить военный самолёт в пресс служба западный военный округа уточнять что тренировочный пролёт экипаж оперативно тактический армейский и транспортный авиация над город не занять более 10 минута ранее фонтанка писать что экипаж оперативно тактический и армейский авиация зво впервые принять участие в парад в небо над дворцовый площадь можно быть увидеть большой 40 единица техника включая вертолёт истребитель и транспортный самолёт кроме тот в десять часы вечер состояться наземный часть репетиция парад победа решение о перенос на более поздний время принять после тот как один день ежегодный предпраздничный мероприятие с самый утро обернуться безумие для автомобилист 5 май состояться ещё один тренировка парад а на 7 май наметить генеральный репетиция\n'},
#     '_type': 'new'},
#    {'_id': '5144',
#     '_index': 'news-index',
#     '_score': 8.15783,
#     '_source': {'content': 'общественный транспорт поменять маршрут из за военный морской парад на нева несколько автобус и трамвай поменять маршрут в связь с репетиция и проведение военный морской парад в петербург прогулочный катер также пустить не везде как рассказать журналист на брифинг 17 июль представитель организационный штаб в день проведение тренировка и самый парад некоторый маршрут наземный пассажирский транспорт быть работать по укоротить трасса или оказаться закрытый в частность при разведение троицкий мост изменить схема движение автобус 46 и 49 перекрытие литейный мост повлиять на следование 3 го трамвай а также 3 го и 8 го троллейбус из за дворцовый мост поменять траектория автобус 7 10 23 191 и троллейбус 1 7 10 11 закрытие благовещенский мост остановить маршрут 6 го автобус у станция метро василеостровский 15 17 18 21 июль до 6 00 для просмотр в полный размер кликнуть мышка для просмотр в полный размер кликнуть мышка ранее фонтанка писать о план чиновник по перекрытие движение в центр город в частность четыре мост развести 23 28 и 30 июль в 9 25 23 и 30 июль они быть свести в 11 50 а 28 июль только в 13 20 на это время центральный участок зсд сделать бесплатный сообщаться также что экскурсионный прогулочный суд на водный путь город в время проведение мероприятие быть работать по скорректировать маршрут и без выход в нева с 15 июль в связь с подготовка мероприятие перекрыть зимний канавка и фонтанка справка 30 июль в петербург и кронштадт с размах отпраздновать день военный морской флот в немой принять участие корабль северный балтийский и черноморский флот а также морской авиация тихоокеанский флот\n'},
#     '_type': 'new'},
#    {'_id': '5187',
#     '_index': 'news-index',
#     '_score': 8.144831,
#     '_source': {'content': 'на нева пройти ночной тренировка главный военный морской парад на нева пройти ночной тренировка главный военный морской парад под руководство главком вмф россия сообщать 21 июль минобороны россия в она принять участие более 20 боев корабль и катер вмф россия среди они новый фрегат адмирал макаров корвет стойкий большой десантный корабль минск дизель электрический подводный лодка дмитр а также противолодочный минный тральный и ракетный корабль противодиверсионный патрульный катер и десантный катер руководство тренировка осуществлять главнокомандующий вмф адмирал владимир королева вопрос навигационный обеспечение прохождение корабль от благовещенский до троицкий мост проверить главный штурман вмф контры адмирал эдуард луйк организация связь между корабль и катер кильватерный строй и парадный линия быть отработать под руководство начальник управление связь вмф контры адмирал владимир земсков вопрос движение на задать скорость ход и работа электромеханический боев часть корабль проверить заместитель главком вмф по вооружение вица адмирал виктор бурсука начальник управление боев подготовка вмф контры адмирал виктор кочемаз проверить эпизод прохождение тактический группа корабль а также временной интервал согласно сценарий главный военный морской парад в ход тренировка проверяться работа электромеханический боев часть корабль при движение корабль на установленный скорость точность удержание курс и дистанция в строй кильватер с использование бортовый радиолокационный навигационный комплекс береговой ориентир и реперный точка при прохождение корабль фарватер река и развести мост в ближний день в акватория нева и кронштадт пройти ещё ряд репетиция главный военный морской парад который состояться 30 июль\n'},
#     '_type': 'new'},
#    {'_id': '3126',
#     '_index': 'news-index',
#     '_score': 7.960631,
#     '_source': {'content': 'парад к день вмф на нева особый место в парад занимать вернуться из ремонт крейсер аврор на борт который подняться президент рф и поприветствовать военный экипаж кадр из трансляция канал санкт петербург для просмотр в полный размер кликнуть мышка также в парадное строй между благовещенский и дворцовый мост дизель электрический подводный лодка новое проект краснодар корвет бойкий фрегат адмирал эссный малое противолодочный корабль уренгой и казанец базовый и рейдовый тральщик ракетный катер и гидрографический суд находиться заблаговещенский мост у английский набережная и набережная лейтенант шмидт ранее фонтанка писать что в новый история российский флот это один парад в который участвовать самый современный корабль ради проход яхта владимир путин внеурочно быть развести дворцовый мост фонтанка ру для просмотр в полный размер кликнуть мышка сергей михайличенко для просмотр в полный размер кликнуть мышка фонтанка ру для просмотр в полный размер кликнуть мышка в настоящее время президентский яхта серафим саровский обходить парадный строить и направляться к памятник основатель флот для возложение венок и цветок фонтанка ру\n'},
#     '_type': 'new'},
#    {'_id': '1769',
#     '_index': 'news-index',
#     '_score': 7.8807483,
#     '_source': {'content': 'video не игрушка солдатик на миллион подарить музей суворов в она в общий сложность 2564 фигурка в точность изображать разный войско гвардейский кавалерия гвардейский жандармский эскадрон гвардейский кирасир дворцовый гренадер конвой кавалергард и пехотный дивизия это точный копия последний парад российский императорский гвардия 1914 год на марсовый половина большой такой парад не быть традиция прерваться из за один один мировой война и революция не игрушка солдатик на миллион подарить музей суворов в 1950 е год этот солдатик начать делать в стокгольм русский эмигрант георгий иванов он быть потомок русский офицер и профессиональный гравёр в работа над макет принимать участие также историк униформист и даже пожилое участник тот самый парад который консультировать иванов работа продолжаться 30 год затем солдатик оказаться у немецкий коллекционер руперт байер когда байер исполниться 80 год он понять что после он кончина наследник распродать уникальный коллекция по часть такой образ они выручить за нея большой но коллекционер не мочь это допустить и предложить музей суворов в санкт петербург купить весь коллекция за символический для такой произведение искусство цена но цена весь равно быть высокий музей начать поиск меценат между тем коллекция солдатик уже быть заявить на аукцион где она уже ждать частное коллекционер буквально за два для до аукцион меценат найтись и сразу же заключить контракт с байер петербургский предприниматель мусса экзек заплатить за солдатик сумма на который можно купить квартира в бывший имперский столица в май 2018 год макет последний парад российский императорский гвардия предстать перед посетитель новое музей оловянный миниатюра который открыться на база музей суворов там быть выставить более 60 000 оловянный солдатик изображать воин весь страна и эпоха\n'},
#     '_type': 'new'},
#    {'_id': '5160',
#     '_index': 'news-index',
#     '_score': 7.8505554,
#     '_source': {'content': 'новый фрегат зайти в нева для парад как стать известно фонтанка 19 июль фрегат зайти в нева для участие в военный морской парад к день вмф несколько день адмирал макаров пробыть в кронштадт вместе с корвет стойкий и сообразительный а также малое ракетный корабль серпухов и гейзер ранее адмирал макаров проходить государственный испытание в морской полигон балтийский флот особый внимание уделить проверка работа силовой установка рулевой устройство вспомогательный механизм средство связь обнаружение и навигация якорный устройство фрегат быть заложить на прибалтийский судостроительный завод янтарь в 2012 год спустить на вода в сентябрь 2015 год это три корабль в серия фрегат проект 11356 разработка ао северный проектный конструкторский бюро строиться по заказ минобороны рф корабль этот серия предназначить для противодействие надводный корабль и подводный лодка отражение атака средство воздушный нападение как самостоятельно так и в состав соединение такой фрегат иметь водоизмещение около 4 тысяча тонна длина 125 метр и скорость до 30 узел владимир бельковый для просмотр в полный размер кликнуть мышка владимир бельковый для просмотр в полный размер кликнуть мышка\n'},
#     '_type': 'new'},
#    {'_id': '1614',
#     '_index': 'news-index',
#     '_score': 7.829858,
#     '_source': {'content': 'video на репетиция военный морской парад шойгу повысить до верховный главнокомандующий ролик появиться на портал youtube 31 июль и уже набрать большой два тысяча просмотр на видео записать отрывок трансляция по весь видимость последний смотр корабль участник главный военный морской парад который в петербург принимать в день военный морской флот президент владимир путин президент на репетиция отсутствовать зато быть сергей шойгу именно к министр оборона и обратиться адмирал с слово товарищ верховный главнокомандующий сила и войско далёкий шойгу слушать не стать и что то бормотать с не слишком довольный вид уйти в сторона за кадр послышаться смех далёкий видно как глава минобороны что то объяснять адмирал кома конкретно непонятно военный снятой с спин в комментарий над инцидент посмеяться некоторый ничто особенный в случиться не увидеть поскольку репетиция это точный копия тот что показать в день вмф и по весь видимость министр оборона на генеральный прогон сыграть роль принимать смотр верховный главнокомандующий владимир путин в главный военный морской парад 30 июль принять участие свыше 90 корабль подводный лодка самолёт и вертолёт вмф в они число самый большой в мир ударный корабль с ядерный энергетический установка пётр великий и дмитрий донский центр праздник стать петербург и кронштадт\n'},
#     '_type': 'new'},
#    {'_id': '4618',
#     '_index': 'news-index',
#     '_score': 7.7782264,
#     '_source': {'content': 'северный корея показать несколько тип собственный ракета на военный парад приурочить к 105 й годовщина с день рождение ким ир сена создатель северокорейский государство и дед нынешний лидер кндр ким чен ына быть продемонстрировать несколько тип образцов военный техника сообщать 15 апрель риа новость ким чен ын лично принимать военный парад на центральный площадь пхеньян перед трибуна на который сидеть лидер государство промаршировать парадное расчёт сухопутный войско спецназ военный морской сила и рабочий крестьянский ополчение в тот число женский батальон кроме тот кндр мочь представить на парад ракетный система залповый огонь ракета малый и средний дальность тип земля земля межконтинентальный баллистический ракета и баллистический ракета подводный лодка образец военный техника проехать перед трибуна на который находиться высокий руководство и порядок 200 иностранный журналист пригласить для освещение мероприятие однако в сила специфика северокорейский техника визуально с точность определить тип демонстрировать ракета не представляться возможный in pics north korea flaunts military might missiles on display at founders day parade https t co wvcgleid3i pic twitter com o2lli2kmau new indian express newindianxpress april 15 2017 при это некоторый представитель мид кндр который сопровождать в пхеньян иностранный журналист уверять что вооружённый сила кндр действительно представить межконтинентальный баллистический ракета и баллистический ракета подводный лодка но вряд ли это можно считать официальный информация завершиться военный часть парад пролёт над площадь самолёт который сложить в небо число 105 в честь день солнце государственный праздник и годовщина с день рождение ким ир сена после проход военный техника и армия по площадь промаршировать несколько тысяча человек приветствовать ким чен ына в тот число студент комсомолец врач спортсмен госслужащий сам ким чен ын после завершение торжественный часть пройти по трибуна приветственно помахать собраться рука президент сша дональд трамп на этот неделя назвать северный корея угроза и обещать позаботиться о она но не сказать какой возможность рассматривать тем время к берег корейский полуостров быть перенаправить ударный авианосный группировка сша в глава с авианосец карл винсон источник риа новость\n'},
#     '_type': 'new'},
#    {'_id': '2490',
#     '_index': 'news-index',
#     '_score': 7.6489353,
#     '_source': {'content': 'число погибший при столкновение автобус с толпа на гаити возрасти до 38 на гаити автобус въехать в толпа пешеход на парад в результат что по последний данные скончаться 38 человек о это сообщать reuters с ссылка на власть страна как сообщаться водитель автобус сбить два человек один из который скончаться после что попытаться скрыться с место дтп однако въехать в группа музыкант в результат инцидент 34 человек скончаться на место четверо в больница также сообщаться о десятка пострадавший после столкновение присутствовать на парад начать забрасывать автобус и проезжать транспортный средство камень ранить другой человек президент гаити жовенель моиза выразить соболезнование родной и близкие погибший и призвать начать расследование инцидент источник газета ru\n'},
#     '_type': 'new'}],
#   'max_score': 9.099816,
#   'total': 61},
#  'timed_out': False,
#  'took': 11}

# %%
a = es.search(index='news-index', doc_type='new', q='парад')
a['hits']['hits'][0]['_source']['content']
# Out:
# 'в петербург пройти очередной репетиция парад к день вмф по нева днём 23 июль пройти не маленький пятнадцать корабль и катер среди который быть ракетный катер серпухов и димитровград противодиверсионный катер плата 349 малый ракетный корабль гейзер на время репетиция быть развести благовещенский дворцовый троицкий и литейный мост над адмиралтейство пролететь несколько самолёт в тот число дозаправщик и истребитель в петербург пройти очередной репетиция парад к день вмф напомнить парад пройти в петербург и кронштадт 30 июль в немой принять участие корабль балтийский черноморский северный флот каспийский флотилия и авиация тихоокеанский флот принимать парад быть президент следующий репетиция наметить на 28 июль\n'

# %%
import telebot

token='492410478:AAHINWUA3xjg682Y_d1XpBYkuse4ujIhW60'
bot = telebot.TeleBot(token)

@bot.message_handler(content_types=["text"])
def repeat_all_messages(message): # TODO: текст сообщения нормализовать
    line = message.text
    a = es.search(index='news', doc_type='new', q=line)    
    bot.send_message(message.chat.id, a['hits']['hits'][0]['_source']['content'])
if __name__ == '__main__':
    bot.polling(none_stop=True)
# Out:
# 2017-12-12 22:53:13,252 (util.py:64 PollingThread) ERROR - TeleBot: "ApiException occurred, args=('A request to the Telegram API was unsuccessful. The server returned HTTP 409 Conflict. Response body:\n[b\'{"ok":false,"error_code":409,"description":"Conflict: terminated by other long poll or webhook"}\']',)
# Traceback (most recent call last):
#   File "C:\Users\Veotani\Anaconda3\lib\site-packages\telebot\util.py", line 58, in run
#     task(*args, **kwargs)
#   File "C:\Users\Veotani\Anaconda3\lib\site-packages\telebot\__init__.py", line 159, in __retrieve_updates
#     updates = self.get_updates(offset=(self.last_update_id + 1), timeout=timeout)
#   File "C:\Users\Veotani\Anaconda3\lib\site-packages\telebot\__init__.py", line 129, in get_updates
#     json_updates = apihelper.get_updates(self.token, offset, limit, timeout, allowed_updates)
#   File "C:\Users\Veotani\Anaconda3\lib\site-packages\telebot\apihelper.py", line 175, in get_updates
#     return _make_request(token, method_url, params=payload)
#   File "C:\Users\Veotani\Anaconda3\lib\site-packages\telebot\apihelper.py", line 56, in _make_request
#     return _check_result(method_name, result)['result']
#   File "C:\Users\Veotani\Anaconda3\lib\site-packages\telebot\apihelper.py", line 75, in _check_result
#     raise ApiException(msg, method_name, result)
# telebot.apihelper.ApiException: A request to the Telegram API was unsuccessful. The server returned HTTP 409 Conflict. Response body:
# [b'{"ok":false,"error_code":409,"description":"Conflict: terminated by other long poll or webhook"}']
# "
